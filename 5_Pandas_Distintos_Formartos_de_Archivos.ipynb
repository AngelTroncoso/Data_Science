# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelTroncoso/Data_Science/blob/main/5_Pandas_Distintos_Formartos_de_Archivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Leyendo Archivos CSV

# %% [markdown]
# ###Importando Archivos

# %%
import pandas as pd

df = pd.read_csv('/content/superstore_data.csv')
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
datos_punto_coma = pd.read_csv('/content/superstore_data_punto_coma.csv', sep = ";")
datos_punto_coma.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
numeros_de_filas = pd.read_csv('/content/superstore_data.csv', nrows= 5)
numeros_de_filas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
n_de_columnas = pd.read_csv('/content/superstore_data.csv', usecols=["Id","Year_Birth","Income"])
n_de_columnas
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
n_de_columnas_n = pd.read_csv('/content/superstore_data.csv', usecols=[0,1,4])
n_de_columnas_n
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ##**Guardar archivos en csv**

# %%
n_de_columnas_n.to_csv('n_de_columnas_n.csv')

# %%
clientes = pd.read_csv('/content/n_de_columnas_n.csv')
clientes.head()
# Out:
#    Unnamed: 0     Id  Year_Birth   Income
# 0           0   1826        1970  84835.0
# 1           1      1        1961  57091.0
# 2           2  10476        1958  67267.0
# 3           3   1386        1967  32474.0
# 4           4   5371        1989  21474.0

# %% [markdown]
# ##**Guardar datos sin indices**

# %%
n_de_columnas_n.to_csv('n_de_columnas_n.csv', index=False)

# %%
n_de_columnas_n = pd.read_csv('/content/n_de_columnas_n.csv')
n_de_columnas_n.head()
# Out:
#       Id  Year_Birth   Income
# 0   1826        1970  84835.0
# 1      1        1961  57091.0
# 2  10476        1958  67267.0
# 3   1386        1967  32474.0
# 4   5371        1989  21474.0

# %% [markdown]
# #**Desafío: leyendo datos con múltiples parámetros:**

# %% [markdown]
# ####**Su desafío aquí será leer este archivo usando la función read_csv de la biblioteca Pandas. Se deben agregar algunos parámetros para que la lectura se realice correctamente. Entonces, aquí hay algunos consejos:**

# %%
import chardet

# %%
with open('/content/datos_sus.csv', 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
datos = pd.read_csv('/content/datos_sus.csv', encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter = 9, engine='python')

# %%
datos.head(9)
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0             Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1                 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2             Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3              Roraima    657889,53    777939,31    718688,03    839994,39
# 4                 Pará  18864744,11  19553758,20  21937342,70  20842829,69
# 5                Amapá   1120973,34   1268740,33    974651,24   1141137,32
# 6            Tocantins   3441592,69   4985688,85   6205612,60   4984482,09
# 7             Maranhão  10723506,39  13559679,41  13985142,36  14809416,46
# 8                Piauí   7985142,43  10079928,25  10298372,45  10775976,33
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
# 5    866346,18   1440978,95   1426659,48   1475551,38   1651341,43  ...
# 6   5511002,46   4927934,22   5445602,28   5413710,38   5596669,50  ...
# 7  14505727,38  14908091,32  15784899,40  15195312,89  14951277,75  ...
# 8  10398360,88  10528253,88  11040107,92  10549176,40  10899198,97  ...
#
#       2020/Jul     2020/Ago     2020/Set     2020/Out     2020/Nov  \
# 0  11824687,13  11733307,76  10201985,14   7955139,45   9357946,29
# 1   3915193,20   3640142,82   3391242,21   4044321,44   3276590,10
# 2  19769460,14  18059931,43  17841015,63  16408315,10  19895617,91
# 3   3015488,30   2826486,18   2928043,91   3090313,73   3621031,05
# 4  40804126,43  44385715,88  36820249,47  36965931,34  39004315,80
# 5   3253399,45   2946398,44   2416019,23   2203732,04   2218532,26
# 6   9155572,36   8390267,72   8729632,49   7770885,66    527840,46
# 7  35473489,49  32219037,29  30077152,72  33200778,47  31942670,33
# 8  19908573,27  25663537,49  20230782,72  22389215,72  18911604,50
#
#       2020/Dez     2021/Jan     2021/Fev     2021/Mar          Total
# 0   8880836,55   9266014,59   7730597,04  11023309,47   996411254,68
# 1   3696997,31   3715723,12   3538427,92   4077045,92   450048530,47
# 2  17765167,69  21430289,17  25917134,55  22032176,22  1917247936,05
# 3   3454460,94   3266928,47   3519773,73   3985530,08   328876965,09
# 4  38015145,79  38354682,46  37688314,23  33276392,89  4705309002,29
# 5   2566919,60   2802886,34   2817849,31   3188210,98   309860092,59
# 6    675277,05    419553,49    319160,87   1357751,33  1020028272,64
# 7  30783403,58  30738750,31  30924484,99  39663677,48  3871069498,04
# 8  20883972,79  22689390,32  19400269,01  20018325,75  2280888802,74
#
# [9 rows x 161 columns]

# %% [markdown]
# ##**Para saber más: error de codificación - ¿cómo solucionarlo?**

# %% [markdown]
# ###**Giovanna es una científica de datos que trabaja en una empresa de comercio electrónico. Ella es responsable de analizar datos de ventas para identificar patrones y tendencias que puedan ayudar a la empresa a tomar decisiones informadas.Recientemente, le asignaron una nueva tarea: analizar un archivo CSV que contiene información sobre las ventas de la empresa durante un período determinado. Para ello, Giovanna intentó leer un archivo CSV en Google Colab, usando la biblioteca Pandas con el siguiente comando:

# %%
#import pandas as pd
#df = pd.read_csv('datos.csv')

# %%
import chardet

# %%
#with open('datos.csv', 'rb') as file:
#    print(chardet.detect(file.read()))

# %%
{'encoding': 'UTF-16', 'confidence': 1.0, 'language': ''}
# Out:
# {'encoding': 'UTF-16', 'confidence': 1.0, 'language': ''}

# %%
#df = pd.read_csv('datos.csv', encoding='UTF-16')

# %% [markdown]
# ###**Aula N°2 Trabajando con archivos de Excel**

# %%
emisiones = pd.read_excel('/content/emisiones_CO2.xlsx')
emisiones
# Out:
#              País ISO 3166-1 alpha-3   Año         Total        Carbón  \
# 0      Afganistán                AFG  1750  0.000000e+00           NaN
# 1      Afganistán                AFG  1751  0.000000e+00           NaN
# 2      Afganistán                AFG  1752  0.000000e+00           NaN
# 3      Afganistán                AFG  1753  0.000000e+00           NaN
# 4      Afganistán                AFG  1754  0.000000e+00           NaN
# ...           ...                ...   ...           ...           ...
# 63099      Global                WLD  2017  3.609674e+10  1.450697e+10
# 63100      Global                WLD  2018  3.682651e+10  1.474683e+10
# 63101      Global                WLD  2019  3.708256e+10  1.472598e+10
# 63102      Global                WLD  2020  3.526409e+10  1.417456e+10
# 63103      Global                WLD  2021  3.712385e+10  1.497960e+10
#
#              Aceite           Gas       Cemento        Quema        Otros  \
# 0               NaN           NaN           NaN          NaN          NaN
# 1               NaN           NaN           NaN          NaN          NaN
# 2               NaN           NaN           NaN          NaN          NaN
# 3               NaN           NaN           NaN          NaN          NaN
# 4               NaN           NaN           NaN          NaN          NaN
# ...             ...           ...           ...          ...          ...
# 63099  1.224263e+10  7.144928e+09  1.507923e+09  391992176.0  302294047.0
# 63100  1.226602e+10  7.529847e+09  1.569218e+09  412115746.0  302478706.0
# 63101  1.234565e+10  7.647528e+09  1.617507e+09  439253991.0  306638573.0
# 63102  1.119181e+10  7.556290e+09  1.637538e+09  407583673.0  296301685.0
# 63103  1.183716e+10  7.921829e+09  1.672592e+09  416525563.0  296145746.0
#
#        Per Capita
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 63099   4749682.0
# 63100   4792753.0
# 63101   4775633.0
# 63102   4497423.0
# 63103   4693699.0
#
# [63104 rows x 11 columns]

# %% [markdown]
# Examinar archivo excele con sus hojas

# %%
# Examinar archivo excele con sus hojas
pd.ExcelFile('/content/emisiones_CO2.xlsx').sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %%
percapita = pd.read_excel('/content/emisiones_CO2.xlsx', sheet_name='emisiones_percapita')
percapita.sample(5)
# Out:
#              País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  \
# 38255     Namibia                NAM  1925    NaN     NaN     NaN  NaN
# 29278      Kuwait                KWT  1924    NaN     NaN     NaN  NaN
# 12090  Islas Cook                COK  1872    NaN     NaN     NaN  NaN
# 4431   Bangladesh                BGD  1829    NaN     NaN     NaN  NaN
# 35454  Mauritania                MRT  1844    NaN     NaN     NaN  NaN
#
#        Cemento  Quema  Otros
# 38255      NaN    NaN    NaN
# 29278      NaN    NaN    NaN
# 12090      NaN    NaN    NaN
# 4431       NaN    NaN    NaN
# 35454      NaN    NaN    NaN

# %%
Fuentes = pd.read_excel('/content/emisiones_CO2.xlsx', sheet_name='fuentes')
Fuentes.sample(5)
# Out:
#                          País ISO 3166-1 alpha-3   Año       Total  \
# 38098                 Namibia                NAM  1768      [NONE]
# 52769  San Cristóbal Y Nieves                KNA  1751      [NONE]
# 28167               Kazajstán                KAZ  1901      [NONE]
# 21727                 Hermoso                GHA  1989  CDIAC 2022
# 33648                  Malaui                MWI  1942      [NONE]
#
#            Carbón      Aceite         Gas        Cemento       Quema   Otros  \
# 38098      [NONE]      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 52769      [NONE]      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 28167      [NONE]      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 21727  CDIAC 2022  CDIAC 2022  CDIAC 2022  Andrew cement  CDIAC 2022  [NONE]
# 33648      [NONE]      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
#
#                          Per Capita
# 38098                        [NONE]
# 52769                        [NONE]
# 28167                        [NONE]
# 21727  CDIAC 2022 and UN population
# 33648                        [NONE]

# %%
intervalo_columna = pd.read_excel('/content/emisiones_CO2.xlsx', sheet_name='emisiones_C02', usecols= 'A:D')
intervalo_columna.sample(5)
# Out:
#             País ISO 3166-1 alpha-3   Año       Total
# 44549   Portugal                PRT  1963  10011581.0
# 22721  Guadalupe                GLP  1895         0.0
# 861      Andorra                AND  1795         0.0
# 3322     Austria                AUT  1808         0.0
# 56404         Ir                TGO  1850         0.0

# %%
intervalo_fila = pd.read_excel('/content/emisiones_CO2.xlsx', sheet_name='emisiones_C02', usecols= 'A:D', nrows = 10)
intervalo_fila
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ###Excel Google sheet

# %%
sheet_id = '1scFa_6PJ1EsXHh3iuflm0P0dJ3Auy4nOzBrYMLP4Mfw'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos_sheet = pd.read_csv(url)
datos_sheet.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750     0    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751     0    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752     0    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753     0    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754     0    NaN    NaN  NaN     NaN   NaN
#
#   Otros Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %%
sheet_id = '1scFa_6PJ1EsXHh3iuflm0P0dJ3Auy4nOzBrYMLP4Mfw'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet=emisiones_percapita'

# %%
percapita_sheet = pd.read_csv(url_percapita)
datos_sheet.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750     0    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751     0    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752     0    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753     0    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754     0    NaN    NaN  NaN     NaN   NaN
#
#   Otros Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %%
sheet_id = '1scFa_6PJ1EsXHh3iuflm0P0dJ3Auy4nOzBrYMLP4Mfw'
url_fuente = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet=fuentes'

# %%
fuente_sheet = pd.read_csv(url_fuente)
fuente_sheet.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
#                     Quema   Otros  \
# 63099  CDIAC 2022 and GCP  [NONE]
# 63100  CDIAC 2022 and GCP  [NONE]
# 63101  CDIAC 2022 and GCP  [NONE]
# 63102  CDIAC 2022 and GCP  [NONE]
# 63103  CDIAC 2022 and GCP  [NONE]
#
#                                               Per Capita
# 63099  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63100  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63101  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63102  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63103  CDIAC 2022, BP, Sum of countries, and UN popul...

# %% [markdown]
# ##**Publicado en la web**

# %% [markdown]
# solo una hoja no requiere autentificaciòn

# %%
import pandas as pd

url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQQYIkYwPDBFtO2rvldVvllxY8mAHoyjrLWN1nzKAgClqnzareaFmQjlJ4cpv7c7UWym8SjdgOSxBlG/pub?output=csv'
df = pd.read_csv(url)
df.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750     0    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751     0    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752     0    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753     0    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754     0    NaN    NaN  NaN     NaN   NaN
#
#   Otros Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %% [markdown]
# ##**Desafío: leyendo datos de otro link**

# %% [markdown]
# ####En este desafío, tu función es leer este link de Google Sheets y luego guardar el DataFrame obtenido en formato CSV. ¿Listo para comenzar?

# %%
sheet_id = '1QXLBXO_47wVw_snMFfL0OgcyZPJqN_KQy0OS6P4GTQc'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos = pd.read_csv(url)
datos.head()
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# 2  543.557.223     70.898.423    836.804.405    912.141.485  ...
# 3  683.699.826    638.307.036    645.355.189    605.436.253  ...
# 4   69.630.787  6.724.177.518  6.541.578.914  6.733.479.486  ...
#
#             2011           2012           2013           2014           2015  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1     29.650.624    259.295.334     18.562.366    146.235.617    172.896.741
# 2    985.522.312    950.695.879  1.036.293.852  1.099.779.111    113.504.405
# 3    166.942.319    150.324.046  1.533.630.039  1.668.337.371    160.377.515
# 4  5.850.886.105  5.944.654.173  5.942.800.412  5.807.127.723  6.026.181.822
#
#             2016           2017           2018           2019         2019.1
# 0            NaN            NaN            NaN            NaN            NaN
# 1    149.789.334    131.694.556      1.632.953    159.824.372    159.824.372
# 2  1.031.811.348     81.330.073    777.674.934    792.137.069    792.137.069
# 3  1.557.664.358  1.788.786.074  1.782.738.948    169.224.832    169.224.832
# 4  6.080.600.282  6.104.133.912  6.362.975.399  6.481.217.432  6.481.217.432
#
# [5 rows x 35 columns]

# %% [markdown]
# ###Guardando el archivo descargado y copiado en mi drive

# %%
datos.to_csv('datos_emisiones_co2.csv', index=False)

# %% [markdown]
# ##**Lectura de datos en formato Json**

# %%
datos_pacientes = pd.read_json("/content/pacientes.json")

# %%
datos_pacientes
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# 0               3            30                 No       Femenino      55-59
# 1               0             0                 No       Femenino     80 ó +
# 2              20            30                 No      Masculino      65-69
# 3               0             0                 No       Femenino      75-79
# 4              28             0                 Sí       Femenino      40-44
# ..            ...           ...                ...            ...        ...
# 995            10            20                 No       Femenino      65-69
# 996             0             0                 No       Femenino      75-79
# 997             1             0                 No      Masculino      70-74
# 998            30             0                 Sí       Femenino      70-74
# 999             0             0                 No      Masculino      70-74
#
#        Raza Diabetes Actividad_fisica Salud_general  Horas_sueño Asma  \
# 0    Blanca       Sí               Sí     Muy buena            5   Sí
# 1    Blanca       No               Sí     Muy buena            7   No
# 2    Blanca       Sí               Sí     Razonable            8   Sí
# 3    Blanca       No               No         Buena            6   No
# 4    Blanca       No               Sí     Muy buena            8   No
# ..      ...      ...              ...           ...          ...  ...
# 995   Negra       Sí               Sí     Razonable            8   No
# 996  Blanca       No               Sí     Excelente            8   No
# 997  Blanca       No               Sí     Muy buena            8   No
# 998  Blanca       Sí               No         Buena            6   Sí
# 999   Negra       Sí               No     Excelente            7   No
#
#     Enfermedad_renal Cancer_piel
# 0                 No          Sí
# 1                 No          No
# 2                 No          No
# 3                 No          Sí
# 4                 No          No
# ..               ...         ...
# 995               No          No
# 996               No          No
# 997               No          No
# 998               No          No
# 999               No          No
#
# [1000 rows x 19 columns]

# %%
datos_pacientes2 = pd.read_json("/content/pacientes_2.json")

# %%
datos_pacientes2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %%
normalizado = pd.json_normalize(datos_pacientes2['Pacientes'])
normalizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ###**Para saber más: profundizando en la normalización**

# %% [markdown]
# ####La normalización de datos es un proceso importante en la ciencia de datos que tiene como objetivo organizar y estandarizar datos para facilitar el análisis y la comparación entre ellos. Cuando se trata de datos en formato JSON (JavaScript Object Notation - Notación de objetos JavaScript), es común que estén anidados, lo que puede dificultar su análisis y manipulación.
#
# ####La biblioteca Pandas cuenta con una función llamada json_normalize() que permite la transformación de datos a formato tabular, facilitando la visualización y análisis de las informaciones. A continuación, aprenderemos cómo usar esta función para normalizar diferentes tipos de JSON en DataFrames.

# %% [markdown]
# ####Normalizacion simple
# A continuación tenemos una variable llamada datos y dentro de ella hay un objeto JSON con tres llaves y sus respectivos valores:

# %%
datos = {'Análisis': 'Principales indicadores de enfermedad cardíaca', 'Año': 2020, 'Numero_Pacientes':3}

# %% [markdown]
# Para normalizar esta variable, podemos pasarla dentro de la función json_normalize y analizar el DataFrame obtenido:

# %%
df = pd.json_normalize(datos)
df
# Out:
#                                          Análisis   Año  Numero_Pacientes
# 0  Principales indicadores de enfermedad cardíaca  2020                 3

# %% [markdown]
# ###**Normalizacion de Json con multiples niveles:**
# Hay situaciones en las que el archivo JSON puede contener más de un objeto, como es el caso del siguiente ejemplo, en el que tenemos una lista, almacenada en la variable json_lista, que contiene dos objetos JSON:

# %%
json_lista = [
    { 'ID': '01', 'Intervalo_edad': '55-59', 'Sexo_biologico': 'femenino'},
    { 'ID': '02', 'Intervalo_edad': '80 ó +', 'Sexo_biologico': 'femenino'}
]

# %% [markdown]
# Para normalizar esta lista podemos aplicar la función json_normalize:

# %%
pd.json_normalize(json_lista)
# Out:
#    ID Intervalo_edad Sexo_biologico
# 0  01          55-59       femenino
# 1  02         80 ó +       femenino

# %% [markdown]
# ##**Normalizando un JSON con una lista anidada**

# %% [markdown]
# ##Datos como un diccionario##
#
# Iniciemos observando la normalización cuando los datos son un diccionario. Tenemos un diccionario almacenado en la variable json_obj. Observe que en la llave “Salud” tenemos otro diccionario:

# %%
json_obj = {
    'ID': '01',
    'Intervalo_edad': '55-59',
    'Sexo_biologico': 'Femenino',
    'Salud': {'Dificultad_caminar': 'No',
              'Actividad_fisica': 'Sí',
              'IMC': 16.6,
              'Enfermedad_cardiaca': 'No',
          }
      }

# %% [markdown]
# Haciendo la normalización:

# %%
pd.json_normalize(json_obj)
# Out:
#    ID Intervalo_edad Sexo_biologico Salud.Dificultad_caminar  \
# 0  01          55-59       Femenino                       No
#
#   Salud.Actividad_fisica  Salud.IMC Salud.Enfermedad_cardiaca
# 0                     Sí       16.6                        No

# %% [markdown]
# ###Datos como una lista de diccionarios.

# %%
json_list = [
    {
    'ID': '01',
    'Intervalo_edad': '55-59',
    'Sexo_biologico': 'Femenino',
    'Salud': {'Dificultad_caminar': 'No',
              'Actividad_fisica': 'Sí',
              'IMC': 16.6,
              'Enfermedad_cardiaca': 'No',
          }
      },
      {
          'ID': '02',
          'Intervalo_edad': '80 ó +',
          'Sexo_biologico': 'Femenino',
          'Salud': {'Dificultad_caminar': 'No',
                    'Actividad_fisica': 'Sí',
                    'IMC': 20.34,
                    'Enfermedad_cardiaca': 'Sí'}
       }
       ]

# %% [markdown]
# Haciendo la normalización:

# %%
pd.json_normalize(json_list)
# Out:
#    ID Intervalo_edad Sexo_biologico Salud.Dificultad_caminar  \
# 0  01          55-59       Femenino                       No
# 1  02         80 ó +       Femenino                       No
#
#   Salud.Actividad_fisica  Salud.IMC Salud.Enfermedad_cardiaca
# 0                     Sí      16.60                        No
# 1                     Sí      20.34                        Sí

# %% [markdown]
# #####**Podemos ver que todos los valores anidados dentro de cada registro de la lista se han convertido en columnas separadas. ¿Qué pasa con los datos que normalizamos en el video anterior? ¿Recuerdas cómo su normalización se hizo de otra manera?**
#
# #####**Resumiendo, vamos a copiar los datos del archivo paciente_2.json y vamos a guardarlos en una variable llamada datos_dict.**

# %%
datos_dict = {
  "Investigación": "Indicadores clave de enfermedades cardíacas",
  "Año": 2020,
  "Pacientes": [
    {
     "ID": "01",
      "Rango_edad": "55-59",
      "Sexo_biologico": "Mujer",
      "Raza": "Blanca",
      "IMC": 16.6,
      "Fumador": "Sí",
      "Consumo_alcohol": "No",
      "Salud_física": 3,
      "Salud_mental": 30,
      "Dificultad_caminar": "No",
      "Actividad_física": "Sí",
      "Salud_general": "Muy buena",
      "Horas_sueño": 5,
      "Problemas_salud": [
        "Diabetes",
        "Asma",
        "Cancer_piel"
      ]
    },
    {
      "ID": "02",
      "Rango_edad": "80 ó +",
      "Sexo_biologico": "Mujer",
      "Raza": "Blanca",
      "IMC": 20.34,
      "Fumador": "No",
      "Consumo_alcohol": "No",
      "Salud_física": 0,
      "Salud_mental": 0,
      "Dificultad_caminar": "No",
      "Actividad_física": "Sí",
      "Salud_general": "Muy buena",
      "Horas_sueño": 7,
      "Problemas_salud": [
        "AVC"
      ]
    },
    {
      "ID": "03",
      "Rango_edad": "65-69",
      "Sexo_biologico": "Masculino",
      "Raza": "Blanca",
      "IMC": 26.58,
      "Fumador": "Sí",
      "Consumo_alcohol": "No",
      "Salud_física": 20,
      "Salud_mental": 30,
      "Dificultad_caminar": "No",
      "Actividad_física": "Sí",
      "Salud_general": "Muy buena",
      "Horas_sueño": 8,
      "Problemas_salud": [
        "Diabetes",
        "Asma"
      ]
    }
  ]
}

# %% [markdown]
# ##Si intentamos normalizar estos datos:

# %%
pd.json_normalize(datos_dict)
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  [{'ID': '01', 'Rango_edad': '55-59', 'Sexo_bio...

# %% [markdown]
# #####Podemos observar que nuestra lista anidada está colocada en una única columna Pacientes. Entonces, usaremos el siguiente código para normalizar los datos, especificando qué columna está anidada:

# %%
pd.json_normalize(datos_dict['Pacientes'])
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# #####También podemos hacer esto usando el parámetro record_path como ['Pacientes']. Este parámetro se utiliza en la función pd.json_normalize() para especificar la ruta a los registros que deben ser normalizados en un DataFrame separado:

# %%
pd.json_normalize(datos_dict, record_path=['Pacientes'])
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ######El resultado parece excelente, pero no incluye las columnas "Investigación" y "Año". Para incluirlas, podemos usar el parámetro meta para especificar otras columnas que queramos en el DataFrame.

# %%
pd.json_normalize(
    datos_dict,
    record_path =['Pacientes'],
    meta=['Investigación', 'Año']
)
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud  \
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]
#
#                                  Investigación   Año
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020

# %% [markdown]
# ####¡De esa manera tenemos todas las columnas presentes en el DataFrame!

# %% [markdown]
# #####Importante: En clase nosotros realizamos la normalización en un archivo con formato JSON. Sin embargo, la función json_normalize() sólo acepta un diccionario o una lista de diccionarios. Por esto, en el video se utilizó la estrategia de usar el código: pd.json_normalize(datos_pacientes_2['Pacientes']). Sin embargo, si intentamos utilizar parámetros de la función json_normalize en un archivo JSON, pueden surgir errores. Para solucionar esto, necesitamos importar el módulo json y leer los archivos según el siguiente código:

# %%
#Importando la biblioteca Pandas
import pandas as pd

#Importando el módulo JSON
import json

#Leyendo el archivo json usando el módulo Python JSON
with open('pacientes_2.json','r') as f:
    datos = json.loads(f.read())

#Normalizando los datos con los parámetros record_path y meta
pd.json_normalize(datos, record_path='Pacientes', meta=['Investigación', 'Año'])
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud  \
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]
#
#                                  Investigación   Año
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020

# %% [markdown]
# ####**Y fue así que aprendimos cómo normalizar archivos JSON simples, con múltiples niveles y anidados.**

# %% [markdown]
# ###**Exportar archivo Json**

# %%
#Importando la biblioteca Pandas
import pandas as pd

#Importando el módulo JSON
import json

#Leyendo el archivo json usando el módulo Python JSON
with open('pacientes_2.json','r') as f:
    datos = json.loads(f.read())

#Normalizando los datos con los parámetros record_path y meta
pd.json_normalize(datos, record_path='Pacientes', meta=['Investigación', 'Año'])

# Crear un DataFrame a partir de json_list
df_json_list = pd.DataFrame(json_list)

# Exportar el DataFrame a un archivo JSON
df_json_list.to_json('yo_asigno_este_nombre.json', index=False)

# %%
pd.read_json('yo_asigno_este_nombre.json')
# Out:
#    ID Intervalo_edad Sexo_biologico  \
# 0   1          55-59       Femenino
# 1   2         80 ó +       Femenino
#
#                                                Salud
# 0  {'Dificultad_caminar': 'No', 'Actividad_fisica...
# 1  {'Dificultad_caminar': 'No', 'Actividad_fisica...

# %% [markdown]
# ##**Para Saber Mas:**
# #####Para obtener datos en formato JSON podemos utilizar una API (Application Programming Interface). Es una interfaz de programación de aplicaciones que permite la comunicación entre diferentes programas o sistemas.
#
# #####Hay varios formatos que se pueden utilizar en las API y uno de los más comunes es JSON (JavaScript Object Notation). JSON es un formato ligero para intercambiar información entre sistemas que utiliza la notación basada en objetos de JavaScript.

# %% [markdown]
# #####Tenemos la siguiente situación-problema:
#
# #####“Una empresa de alimentos saludables tiene problemas con la popularidad de sus productos. A pesar de ofrecer opciones saludables, muchos clientes se muestran reacios a comprar los productos debido a la falta de información sobre los valores nutricionales de las frutas que se utilizan en la producción de alimentos”.
#
# #####Ante esta situación podemos acceder a una API llamada Fruitvice para recopilar información detallada sobre los valores nutricionales de las frutas que se utilizan en los productos. Con esta información, la empresa podrá actualizar sus empaques y materiales de marketing para resaltar los valores nutricionales de las frutas y así atraer más clientes que buscan opciones saludables. Además, la empresa puede utilizar la información para desarrollar nuevos productos que satisfagan aún más las necesidades nutricionales de su clientela.

# %% [markdown]
# ####Una forma común de acceder a las API es a través de la biblioteca requests. Para eso, también es necesario importar el módulo json:

# %%
import requests
import json

# %% [markdown]
# ####Los datos de API Fruitvice se obtendrán con la función request.get('url'). Dentro de ella pasamos la dirección API seguida de api/fruit/all para obtener los datos de todas las frutas.

# %%
datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')

# %% [markdown]
# ####Conseguimos recuperar los resultados utilizando la función json.loads(). Para ello es necesario pasar la variable datos_frutas, previamente creada con el atributo text que devuelve el contenido de la respuesta.

# %%
resultado = json.loads(datos_frutas.text)

# %% [markdown]
# ####Luego podemos obtener una vista previa del DataFrame.

# %%
pd.DataFrame(resultado)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#                                            nutritions
# 0   {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1   {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2   {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3   {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4   {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...
# 5   {'calories': 147, 'fat': 5.3, 'sugar': 6.75, '...
# 6   {'calories': 40, 'fat': 0.4, 'sugar': 4.5, 'ca...
# 7   {'calories': 50, 'fat': 0.34, 'sugar': 5.74, '...
# 8   {'calories': 61, 'fat': 0.5, 'sugar': 9.0, 'ca...
# 9   {'calories': 66, 'fat': 0.44, 'sugar': 15.0, '...
# 10  {'calories': 50, 'fat': 0.12, 'sugar': 9.85, '...
# 11  {'calories': 74, 'fat': 0.3, 'sugar': 16.0, 'c...
# 12  {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 13  {'calories': 97, 'fat': 0.7, 'sugar': 11.2, 'c...
# 14  {'calories': 46, 'fat': 0.28, 'sugar': 9.92, '...
# 15  {'calories': 43, 'fat': 0.2, 'sugar': 8.2, 'ca...
# 16  {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'ca...
# 17  {'calories': 53, 'fat': 0.7, 'sugar': 4.4, 'ca...
# 18  {'calories': 30, 'fat': 0.2, 'sugar': 6.0, 'ca...
# 19  {'calories': 29, 'fat': 0.3, 'sugar': 2.5, 'ca...
# 20  {'calories': 60, 'fat': 0.38, 'sugar': 13.7, '...
# 21  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 22  {'calories': 52, 'fat': 0.4, 'sugar': 10.3, 'c...
# 23  {'calories': 68, 'fat': 1.0, 'sugar': 9.0, 'ca...
# 24  {'calories': 15, 'fat': 0.1, 'sugar': 3.2, 'ca...
# 25  {'calories': 34, 'fat': 0.0, 'sugar': 8.0, 'ca...
# 26  {'calories': 45, 'fat': 0.4, 'sugar': 9.1, 'ca...
# 27  {'calories': 36, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 28  {'calories': 25, 'fat': 0.1, 'sugar': 1.7, 'ca...
# 29  {'calories': 83, 'fat': 1.2, 'sugar': 13.7, 'c...
# 30  {'calories': 60, 'fat': 1.5, 'sugar': 8.0, 'ca...
# 31  {'calories': 69, 'fat': 0.16, 'sugar': 16.0, '...
# 32  {'calories': 43, 'fat': 0.39, 'sugar': 8.1, 'c...
# 33  {'calories': 44, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 34  {'calories': 160, 'fat': 14.66, 'sugar': 0.66,...
# 35  {'calories': 61, 'fat': 0.5, 'sugar': 8.9, 'ca...
# 36  {'calories': 46, 'fat': 0.1, 'sugar': 4.0, 'ca...
# 37  {'calories': 50, 'fat': 0.3, 'sugar': 8.0, 'ca...
# 38  {'calories': 39, 'fat': 0.25, 'sugar': 8.4, 'c...
# 39  {'calories': 95, 'fat': 0.0, 'sugar': 19.1, 'c...
# 40  {'calories': 44, 'fat': 1.26, 'sugar': 0.5, 'c...
# 41  {'calories': 628, 'fat': 61.0, 'sugar': 4.3, '...
# 42  {'calories': 37, 'fat': 0.0, 'sugar': 8.5, 'ca...
# 43  {'calories': 73, 'fat': 0.58, 'sugar': 16.11, ...
# 44  {'calories': 25, 'fat': 0.3, 'sugar': 3.3, 'ca...
# 45  {'calories': 70, 'fat': 0.2, 'sugar': 13.0, 'c...
# 46  {'calories': 39, 'fat': 0.3, 'sugar': 4.4, 'ca...
# 47  {'calories': 92, 'fat': 0.29, 'sugar': 3.4, 'c...
# 48  {'calories': 47, 'fat': 0.3, 'sugar': 8.1, 'ca...

# %% [markdown]
# ####¡Ahora sabemos cómo utilizar la biblioteca requests y el módulo JSON para obtener datos de las API!

# %% [markdown]
# ##**Desafio**

# %% [markdown]
# Es el momento de poner a prueba tus conocimientos adquiridos durante la clase. El DataFrame que se muestra a continuación se generó después de obtener los datos de la API de Fruitvice:
# Este DataFrame tiene 6 columnas: genus (género), name (nombre), id, family (familia), order (orden) e nutritions (nutriciones). Observe que la columna nutritions tiene toda la información nutricional anidada en ella. Por tanto, es necesario normalizar los datos.
#
# El desafío ahora es normalizar este DataFrame.

# %%
import requests
import json

datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')
resultado = json.loads(datos_frutas.text)

# %%
import pandas as pd
datos_frutas_normalizado = pd.json_normalize(resultado)

# %%
datos_frutas_normalizado
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   34            0.00              8.00
# 26                   45            0.40              9.10
# 27                   36            0.40              3.00
# 28                   25            0.10              1.70
# 29                   83            1.20             13.70
# 30                   60            1.50              8.00
# 31                   69            0.16             16.00
# 32                   43            0.39              8.10
# 33                   44            0.40              3.00
# 34                  160           14.66              0.66
# 35                   61            0.50              8.90
# 36                   46            0.10              4.00
# 37                   50            0.30              8.00
# 38                   39            0.25              8.40
# 39                   95            0.00             19.10
# 40                   44            1.26              0.50
# 41                  628           61.00              4.30
# 42                   37            0.00              8.50
# 43                   73            0.58             16.11
# 44                   25            0.30              3.30
# 45                   70            0.20             13.00
# 46                   39            0.30              4.40
# 47                   92            0.29              3.40
# 48                   47            0.30              8.10
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                      8.00                0.00
# 26                      8.30                0.00
# 27                      7.00                1.00
# 28                      8.40                0.30
# 29                     18.70                1.70
# 30                      9.00                9.00
# 31                     18.10                0.72
# 32                      9.80                1.44
# 33                      8.00                0.60
# 34                      8.53                2.00
# 35                     14.60                1.14
# 36                     12.20                0.40
# 37                     12.00                1.00
# 38                      9.50                0.90
# 39                     23.20                1.72
# 40                      7.56                1.78
# 41                     17.00               15.00
# 42                      9.67                0.82
# 43                     17.91                0.41
# 44                      4.60                1.10
# 45                     19.00                0.60
# 46                      5.80                0.50
# 47                     19.10                1.50
# 48                      9.60                1.20

# %% [markdown]
# ##**Importando Pàginas Web**

# %%
import pandas as pd

# %%
datos_html = pd.read_html("/content/peliculas_wikipedia.html")

# %%
datos_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
#  ..                           ...           ...                   ...
#  95                 The Searchers          1956             John Ford
#  96              Bringing Up Baby          1938          Howard Hawks
#  97                    Unforgiven          1992        Clint Eastwood
#  98  Guess Who's Coming to Dinner          1967        Stanley Kramer
#  99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                        Production companies  Rank
#  0                       RKO Radio Pictures     1
#  1                    Warner Bros. Pictures     2
#  2   Paramount Pictures, Alfran Productions     3
#  3          Selznick International Pictures     4
#  4                         Horizon Pictures     5
#  ..                                     ...   ...
#  95                  C. V. Whitney Pictures    96
#  96                      RKO Radio Pictures    97
#  97                     The Malpaso Company    98
#  98                       Columbia Pictures    99
#  99                   Warner Bros. Pictures   100
#
#  [100 rows x 5 columns],
#            hidevteAFI's 100 Years...100 Movies (1998)  \
#  0  Citizen Kane (1941) Casablanca (1942) The Godf...
#
#          hidevteAFI's 100 Years...100 Movies (1998).1
#  0  Citizen Kane (1941) Casablanca (1942) The Godf...  ]

# %%
type(datos_html)
# Out:
# list

# %%
len(datos_html)
# Out:
# 3

# %%
top_peliculas = datos_html[1]

# %%
top_peliculas
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# 1                    Warner Bros. Pictures     2
# 2   Paramount Pictures, Alfran Productions     3
# 3          Selznick International Pictures     4
# 4                         Horizon Pictures     5
# ..                                     ...   ...
# 95                  C. V. Whitney Pictures    96
# 96                      RKO Radio Pictures    97
# 97                     The Malpaso Company    98
# 98                       Columbia Pictures    99
# 99                   Warner Bros. Pictures   100
#
# [100 rows x 5 columns]

# %%
top_peliculas.to_html('top_peliculas.html', index=False)

# %%
pd.read_html('/content/top_peliculas.html')
# Out:
# [                            Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
#  ..                           ...           ...                   ...
#  95                 The Searchers          1956             John Ford
#  96              Bringing Up Baby          1938          Howard Hawks
#  97                    Unforgiven          1992        Clint Eastwood
#  98  Guess Who's Coming to Dinner          1967        Stanley Kramer
#  99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                        Production companies  Rank
#  0                       RKO Radio Pictures     1
#  1                    Warner Bros. Pictures     2
#  2   Paramount Pictures, Alfran Productions     3
#  3          Selznick International Pictures     4
#  4                         Horizon Pictures     5
#  ..                                     ...   ...
#  95                  C. V. Whitney Pictures    96
#  96                      RKO Radio Pictures    97
#  97                     The Malpaso Company    98
#  98                       Columbia Pictures    99
#  99                   Warner Bros. Pictures   100
#
#  [100 rows x 5 columns]]

# %%
top_peliculas.to_csv('top_peliculas_1998.csv', index=False)

# %%
datos = pd.read_csv('/content/top_peliculas_1998.csv')
datos.head()
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %% [markdown]
# ##**Importando Informacion en HTML**

# %%
import pandas as pd

# %%
datos_xml = pd.read_xml('/content/imdb_top_1000.xml')

# %%
datos_xml.head(3)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444

# %%
#se puede guardar en el tipo de archivo que uno prefiera en este caso de Html A Csv.
datos_xml.to_csv('datos_xml.csv', index=False)

# %% [markdown]
# ##**Desafío: leer una tabla de una página web**

# %%
pd.read_html('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n')[0]
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/7/2025[7]​  \
# 0                                        1 417 492 000
# 1                                        1 407 934 000
# 2                                          342 181 000
# 3                                          285 783 000
# 4                                          256 204 000
# ..                                                 ...
# 241                                                600
# 242                                                100
# 243                                                 30
# 244                                      8 083 454 000
# 245  Proyección exponencial de la población al 1/7/...
#
#      Total mun- dial (%) Cambio medio anual (%)[8]​  \
# 0                   1754                        090
# 1                   1742                       -005
# 2                    423                        061
# 3                    354                        117
# 4                    317                        256
# ..                   ...                        ...
# 241                  000                        174
# 242                  000                       -496
# 243                  000                       -111
# 244                10000                        103
# 245  Total mun- dial (%)     Cambio medio anual (%)
#
#      Cambio absoluto anual promedio  Cambio medio abs. total anual (%)  \
# 0                        12 692 000                               1523
# 1                        -1 390 000                                  -
# 2                         2 084 000                                250
# 3                         3 337 000                                400
# 4                         6 567 000                                788
# ..                              ...                                ...
# 241                               0                                000
# 242                               0                                000
# 243                               0                                000
# 244                      83 361 000                              10000
# 245  Cambio absoluto anual promedio  Cambio medio abs. total anual (%)
#
#     Años para even- tual du- pli- ca- ción[9]​  \
# 0                                           78
# 1                                            -
# 2                                          114
# 3                                           60
# 4                                           27
# ..                                         ...
# 241                                         40
# 242                                          -
# 243                                          -
# 244                                         68
# 245     Años para even- tual du- pli- ca- ción
#
#     Censo más reciente, última estimación oficial, proyección de la ONU o reloj de población nacional  \
# 0                                        1 417 492 000
# 1                                        1 408 280 000
# 2                                          341 769 000
# 3                                          282 477 584
# 4                                          241 499 431
# ..                                                 ...
# 241                                                593
# 242                                                190
# 243                                                 35
# 244                                      8 200 791 000
# 245  Censo más reciente, última estimación oficial,...
#
#     Fecha de esta última cifra de población en particular (d/mm/aaaa)[10]​  \
# 0                                            1/07/2025
# 1                                           31/12/2024
# 2                                           13/05/2025
# 3                                           30/06/2024
# 4                                            1/03/2023
# ..                                                 ...
# 241                                         11/08/2021
# 242                                          1/04/2010
# 243                                          1/07/2023
# 244                                         13/05/2025
# 245  Fecha de esta última cifra de población en par...
#
#     Tipo[11]​  \
# 0           A
# 1           E
# 2           R
# 3           E
# 4           C
# ..        ...
# 241         C
# 242         C
# 243         E
# 244         R
# 245      Tipo
#
#     Enlace o hipervínculo (usualmente de tipo oficial) de esta última cifra de población
# 0                                      web.archive.org
# 1                                     www.stats.gov.cn
# 2                                       www.census.gov
# 3                    dispendukcapil.acehtimurkab.go.id
# 4                                       www.pbs.gov.pk
# ..                                                 ...
# 241                              www.citypopulation.de
# 242                                   www.statoids.com
# 243                                 www.immigration.pn
# 244                              www.worldometers.info
# 245  Enlace o hipervínculo (usualmente de tipo ofic...
#
# [246 rows x 12 columns]

# %% [markdown]
# ##**Creando un bancos de datos local**

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, Column, Integer, String, Text

# %%
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# ###Para saber más: bases de datos y SQLAlchemy
#
# Las bases de datos son sistemas que permiten el almacenamiento, organización y recuperación de información de forma estructurada y eficiente. Se utilizan ampliamente en muchas áreas, desde la gestión empresarial hasta la investigación científica. Una base de datos bien diseñada puede mejorar significativamente la eficiencia y precisión de las operaciones de una organización.
#
# Existen bases de datos relacionales y no relacionales. Las bases de datos relacionales representan y almacenan datos en tablas. Las bases de datos no relacionales, también conocidas como bases de datos NoSQL (Not Only SQL - No Sólo SQL), utilizan una variedad de estructuras de datos, como documentos, gráfos o pares llave-valor.
#
# Python ofrece varios paquetes y bibliotecas para trabajar con bases de datos, incluyendo SQLite, MySQL, PostgreSQL, Oracle, MongoDB, entre otros. Uno de los paquetes más comunes utilizados para trabajar con bases de datos relacionales en Python es el paquete sqlite3 que ofrece soporte a bases de datos SQLite. Esta base de datos es liviana e integrada, no requiere un servidor separado para ejecutarse y está instalada de forma nativa en Google Colab.
#
# Para trabajar con esta base de datos, podemos usar SQLAlchemy, una biblioteca de mapeo objeto-relacional (ORM), que permite interactuar con bases de datos relacionales usando código Python. Proporciona una capa de abstracción que permite a los desarrolladores trabajar con objetos Python en lugar de lidiar directamente con las complejidades del lenguaje SQL (Structured Query Language - Lenguaje de consulta estructurado).
#
# Uno de los principales beneficios de utilizar SQLAchemy es la capacidad de crear código más legible y fácil de mantener. Con SQLAlchemy, las operaciones de la base de datos se realizan utilizando métodos en objetos Python, lo que hace que el código sea más claro y menos propenso a errores.
#
# Además, SQLAlchemy ofrece soporte a consultas complejas en bases de datos, lo que permite a los desarrolladores extraer fácilmente información relevante de grandes conjuntos de datos. Esto es especialmente útil en aplicaciones que necesitan manejar grandes cantidades de datos.

# %% [markdown]
# ##**Escribiendo una base de datos**

# %%
import pandas as pd

# %%
archivo = '/content/clientes_banco.csv'

# %%
datos = pd.read_csv(archivo)

# %%
datos.head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable               2
# 1     5008805    32    Nivel superior  Relación-estable               2
# 2     5008806    58  Nivel intermedio            Casado               2
# 3     5008808    52  Nivel intermedio           Soltero               1
# 4     5008809    52  Nivel intermedio           Soltero               1
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro             12           427500.0
# 1           Empleado       Otro             12           427500.0
# 2           Empleado  Seguridad              3           112500.0
# 3   Business Partner     Ventas              8           270000.0
# 4   Business Partner     Ventas              8           270000.0
#
#    Tiene_carro                  Vivienda
# 0            1    Departamento alquilado
# 1            1    Departamento alquilado
# 2            1  Casa/Departamento propio
# 3            0  Casa/Departamento propio
# 4            0  Casa/Departamento propio

# %%
datos.to_sql('clientes', engine, index = False)
# Out:
# 438463

# %%
#debe ser este nombre por convensión de python y libreria
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %% [markdown]
# ##**Leyendo consultas en SQL**

# %%
query = 'SELECT * FROM clientes WHERE Categoria_de_renta = "Empleado"'

# %%
from sqlalchemy import text # Import the text construct

empleados = pd.read_sql(sql=text(query), con=engine.connect()) # Call the connect() method

# %%
empleados
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3                Empleado        Contabilidad              2
# 4                Empleado        Contabilidad              2
# ...                   ...                 ...            ...
# 226054           Empleado                Otro              7
# 226055           Empleado                Otro              7
# 226056           Empleado  Construcción Civil              5
# 226057           Empleado  Construcción Civil              8
# 226058           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            1  Casa/Departamento propio
# 4                270000.0            1  Casa/Departamento propio
# ...                   ...          ...                       ...
# 226054           355050.0            1  Casa/Departamento propio
# 226055           355050.0            1  Casa/Departamento propio
# 226056           135000.0            1  Casa/Departamento propio
# 226057           103500.0            0  Casa/Departamento propio
# 226058           121500.0            0  Casa/Departamento propio
#
# [226059 rows x 11 columns]

# %%
empleados.to_sql('empleados', con = engine.connect(), index=False)
# Out:
# 226059

# %%
#Leer la nueva tabla creada
pd.read_sql_table('empleados', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3                Empleado        Contabilidad              2
# 4                Empleado        Contabilidad              2
# ...                   ...                 ...            ...
# 226054           Empleado                Otro              7
# 226055           Empleado                Otro              7
# 226056           Empleado  Construcción Civil              5
# 226057           Empleado  Construcción Civil              8
# 226058           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            1  Casa/Departamento propio
# 4                270000.0            1  Casa/Departamento propio
# ...                   ...          ...                       ...
# 226054           355050.0            1  Casa/Departamento propio
# 226055           355050.0            1  Casa/Departamento propio
# 226056           135000.0            1  Casa/Departamento propio
# 226057           103500.0            0  Casa/Departamento propio
# 226058           121500.0            0  Casa/Departamento propio
#
# [226059 rows x 11 columns]

# %%
#Para selecionar algunas columnas
pd.read_sql_table('empleados', con = engine.connect(), columns=['ID_Cliente', 'Edad', 'Años_empleado'])
# Out:
#         ID_Cliente  Edad  Años_empleado
# 0          5008804    32             12
# 1          5008805    32             12
# 2          5008806    58              3
# 3          5008815    46              2
# 4          5112956    46              2
# ...            ...   ...            ...
# 226054     6837905    43              7
# 226055     6837906    43              7
# 226056     6839936    34              5
# 226057     6840222    43              8
# 226058     6842885    51              3
#
# [226059 rows x 3 columns]

# %% [markdown]
# ##**Actualizando una base de datos**

# %%
query = 'SELECT * FROM clientes'

# %%
pd.read_sql(sql=text(query), con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3        Business Partner              Ventas              8
# 4        Business Partner              Ventas              8
# ...                   ...                 ...            ...
# 438458        Pensionista                Otro              0
# 438459           Empleado  Construcción Civil              8
# 438460   Business Partner              Ventas              1
# 438461        Pensionista                Otro              0
# 438462           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            0  Casa/Departamento propio
# 4                270000.0            0  Casa/Departamento propio
# ...                   ...          ...                       ...
# 438458           135000.0            0  Casa/Departamento propio
# 438459           103500.0            0  Casa/Departamento propio
# 438460            54000.0            0       Vive con los padres
# 438461            72000.0            0  Casa/Departamento propio
# 438462           121500.0            0  Casa/Departamento propio
#
# [438463 rows x 11 columns]

# %%
#Borrando registros
from sqlalchemy.exc import SQLAlchemyError
query = 'DELETE FROM clientes WHERE ID_Cliente = 5008804'
try:
    r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
    print(e)
else:
    print("#Registros Borrados: ", r_set.rowcount)
# Out:
# #Registros Borrados:  1

# %%
pd.read_sql_table('clientes', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52  Nivel intermedio           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado           Seguridad              3
# 2        Business Partner              Ventas              8
# 3        Business Partner              Ventas              8
# 4        Business Partner              Ventas              8
# ...                   ...                 ...            ...
# 438457        Pensionista                Otro              0
# 438458           Empleado  Construcción Civil              8
# 438459   Business Partner              Ventas              1
# 438460        Pensionista                Otro              0
# 438461           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                112500.0            1  Casa/Departamento propio
# 2                270000.0            0  Casa/Departamento propio
# 3                270000.0            0  Casa/Departamento propio
# 4                270000.0            0  Casa/Departamento propio
# ...                   ...          ...                       ...
# 438457           135000.0            0  Casa/Departamento propio
# 438458           103500.0            0  Casa/Departamento propio
# 438459            54000.0            0       Vive con los padres
# 438460            72000.0            0  Casa/Departamento propio
# 438461           121500.0            0  Casa/Departamento propio
#
# [438462 rows x 11 columns]

# %%
#Actualizando registros

query = "UPDATE clientes SET Grado_estudio='Nivel superior' WHERE ID_Cliente=5008808"
try:
    r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
    print(e)
else:
    print("#Registros Actualizados: ", r_set.rowcount)
# Out:
# #Registros Actualizados:  1

# %%
pd.read_sql_table('clientes', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52    Nivel superior           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado           Seguridad              3
# 2        Business Partner              Ventas              8
# 3        Business Partner              Ventas              8
# 4        Business Partner              Ventas              8
# ...                   ...                 ...            ...
# 438457        Pensionista                Otro              0
# 438458           Empleado  Construcción Civil              8
# 438459   Business Partner              Ventas              1
# 438460        Pensionista                Otro              0
# 438461           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                112500.0            1  Casa/Departamento propio
# 2                270000.0            0  Casa/Departamento propio
# 3                270000.0            0  Casa/Departamento propio
# 4                270000.0            0  Casa/Departamento propio
# ...                   ...          ...                       ...
# 438457           135000.0            0  Casa/Departamento propio
# 438458           103500.0            0  Casa/Departamento propio
# 438459            54000.0            0       Vive con los padres
# 438460            72000.0            0  Casa/Departamento propio
# 438461           121500.0            0  Casa/Departamento propio
#
# [438462 rows x 11 columns]

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['clientes', 'empleados']

# %% [markdown]
# ##**Desafío: manipulando una base de datos**

# %% [markdown]
# ##Tu misión es:
#
# Crear la base de datos local con la biblioteca SQLAlchemy.
# Escribir los datos del archivo CSV en esta base de datos local.
# Realizar tres actualizaciones en la base de datos:
# Actualizar el registro del cliente ID 6840104 cuyo rendimiento anual cambió a 300000.
# Eliminar el registro de cliente ID 5008809, ya que esta persona ya no tiene cuenta en la institución financiera.
# Crear un nuevo registro de cliente siguiendo las especificaciones a continuación:
# ID_cliente: 6850985
# Edad: 33
# Grado_estudio: Doctorado
# Estado_civil: Soltero
# Tamaño_familia: 1
# Categoria_de_renta: Empleado
# Ocupacion: TI
# Años_empleado: 2
# Rendimiento_anual: 290000
# Tiene_carro: 0
# Vivienda: Casa/Departamento propio
# Consejo importante: Para agregar un nuevo cliente a la tabla, use la cláusula INSERT INTO seguida del nombre de la tabla y luego especifique los nombres de las columnas de la tabla entre paréntesis. Utilice la cláusula VALUES y luego pase entre paréntesis los nuevos valores para este nuevo registro. Asegúrese de que los valores estén en el orden correcto y en el formato adecuado para cada columna.

# %% [markdown]
# ##**Opinion del instructor**

# %% [markdown]
# Para crear la base de datos local es necesario ejecutar los siguientes comandos. Este código consiste en importar la biblioteca sqlalchemy y crear un objeto engine que representa una conexión a una base de datos SQLite en memoria. El método create_engine se utiliza para crear el objeto engine y especificar la base de datos que se utilizará. En este caso, la base de datos es una base de datos SQLite en memoria, que se crea usando sqlite:///:memory::

# %%
import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, inspect, text
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# A continuación, podemos leer los datos con la función read_csv y escribirlos en el formato de la base de datos con la función to_sql:

# %%
import pandas as pd
archivo = 'clientes_banco.csv'
datos = pd.read_csv(archivo)
datos.to_sql('clientes', engine, index=False)
# Out:
# 383224

# %% [markdown]
# Después de crear la tabla, podemos obtener un DataFrame con la función read_sql_table:

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804  32.0    Nivel superior  Relación-estable             2.0
# 1          5008805  32.0    Nivel superior  Relación-estable             2.0
# 2          5008806  58.0  Nivel intermedio            Casado             2.0
# 3          5008808  52.0  Nivel intermedio           Soltero             1.0
# 4          5008809  52.0  Nivel intermedio           Soltero             1.0
# ...            ...   ...               ...               ...             ...
# 383219     6689092  57.0    Nivel superior            Casado             2.0
# 383220     6689093  57.0    Nivel superior            Casado             2.0
# 383221     6618205  52.0  Nivel intermedio  Relación-estable             2.0
# 383222     6690761  52.0  Nivel intermedio  Relación-estable             2.0
# 383223          66   NaN              None              None             NaN
#
#        Categoria_de_renta         Ocupacion  Años_empleado  Rendimiento_anual  \
# 0                Empleado              Otro           12.0           427500.0
# 1                Empleado              Otro           12.0           427500.0
# 2                Empleado         Seguridad            3.0           112500.0
# 3        Business Partner            Ventas            8.0           270000.0
# 4        Business Partner            Ventas            8.0           270000.0
# ...                   ...               ...            ...                ...
# 383219   Business Partner          Gerencia           15.0           189000.0
# 383220   Business Partner          Gerencia           15.0           189000.0
# 383221           Empleado  Equipo principal            2.0            90000.0
# 383222           Empleado  Equipo principal            2.0            90000.0
# 383223               None              None            NaN                NaN
#
#         Tiene_carro                  Vivienda
# 0               1.0    Departamento alquilado
# 1               1.0    Departamento alquilado
# 2               1.0  Casa/Departamento propio
# 3               0.0  Casa/Departamento propio
# 4               0.0  Casa/Departamento propio
# ...             ...                       ...
# 383219          1.0  Casa/Departamento propio
# 383220          1.0  Casa/Departamento propio
# 383221          0.0  Casa/Departamento propio
# 383222          0.0  Casa/Departamento propio
# 383223          NaN                      None
#
# [383224 rows x 11 columns]

# %% [markdown]
# ¡Ahora vamos a comenzar las actualizaciones de la base de datos!
#
# Actualizar el registro del cliente ID 6840104 cuyo rendimiento anual cambió a 300000:
#
# El siguiente código actualiza el rendimiento anual del ID de cliente 6840104 en la tabla clientes. La variable query contiene una declaración SQL que actualiza ese registro. Luego, la declaración engine.connect() se usa para crear una conexión a la base de datos SQLite. Finalmente, la declaración .execute(text(query)) se utiliza para ejecutar la declaración SQL contenida en la variable query y actualizar el registro en la tabla clientes.

# %%
from sqlalchemy.exc import SQLAlchemyError
query = 'UPDATE clientes SET Rendimiento_anual=300000.0 WHERE ID_Cliente=6840104'
try:
  r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros actualizados: ",r_set.rowcount)
# Out:
# #Registros actualizados:  0

# %% [markdown]
# Eliminar el registro de cliente ID 5008809, ya que esta persona ya no tiene una cuenta en la institución financiera:

# %%
from sqlalchemy.exc import SQLAlchemyError
query = 'DELETE FROM clientes WHERE ID_Cliente=5008809'
try:
  r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros borrados: ",r_set.rowcount)
# Out:
# #Registros borrados:  1

# %% [markdown]
# Cree un nuevo registro de cliente siguiendo las especificaciones dadas anteriormente:
#
# Al trabajar con bases de datos, es común necesitar insertar nuevos registros en nuestras tablas. Para ello podemos utilizar la cláusula INSERT INTO que nos permite añadir nuevos datos de forma práctica y rápida.
#
# Para utilizar esta cláusula, primero debe especificar el nombre de la tabla en la que se insertará el registro. A continuación, debemos pasar entre paréntesis los nombres de las columnas donde se agregarán los nuevos valores. Es importante recordar que el orden de los nombres debe ser el mismo orden en el que se pasarán los valores.
#
# Después de especificar las columnas, usamos la cláusula VALUES para agregar los nuevos valores. Nuevamente debemos pasar entre paréntesis los valores a insertar en el mismo orden en que se especificaron las columnas. Es importante asegurarse de que los valores estén en el formato correcto para cada tipo de datos.
#
# Como la `query` es larga, puedes usar `' \` para indicar que el código continúa en la siguiente línea.

# %%
from sqlalchemy.exc import SQLAlchemyError
query = 'INSERT INTO clientes (ID_Cliente, Edad, Grado_estudio, Estado_civil, ' \
        'Tamaño_familia, Categoria_de_renta, Ocupacion, Años_empleado, ' \
        'Rendimiento_anual, Tiene_carro, Vivienda) ' \
        'VALUES (6850985, 33, "Doctorado", "Soltero", 1, "Empleado", "TI", ' \
        '2, 290000, 0, "Casa/Departamento propio")'

try:
  r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros insertados: ",r_set.rowcount)
# Out:
# #Registros insertados:  1

# %% [markdown]
# Para verificar que se realizaron los cambios, puede leer la tabla con el siguiente código:

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804  32.0    Nivel superior  Relación-estable             2.0
# 1          5008805  32.0    Nivel superior  Relación-estable             2.0
# 2          5008806  58.0  Nivel intermedio            Casado             2.0
# 3          5008808  52.0  Nivel intermedio           Soltero             1.0
# 4          5008810  52.0  Nivel intermedio           Soltero             1.0
# ...            ...   ...               ...               ...             ...
# 383219     6689093  57.0    Nivel superior            Casado             2.0
# 383220     6618205  52.0  Nivel intermedio  Relación-estable             2.0
# 383221     6690761  52.0  Nivel intermedio  Relación-estable             2.0
# 383222          66   NaN              None              None             NaN
# 383223     6850985  33.0         Doctorado           Soltero             1.0
#
#        Categoria_de_renta         Ocupacion  Años_empleado  Rendimiento_anual  \
# 0                Empleado              Otro           12.0           427500.0
# 1                Empleado              Otro           12.0           427500.0
# 2                Empleado         Seguridad            3.0           112500.0
# 3        Business Partner            Ventas            8.0           270000.0
# 4        Business Partner            Ventas            8.0           270000.0
# ...                   ...               ...            ...                ...
# 383219   Business Partner          Gerencia           15.0           189000.0
# 383220           Empleado  Equipo principal            2.0            90000.0
# 383221           Empleado  Equipo principal            2.0            90000.0
# 383222               None              None            NaN                NaN
# 383223           Empleado                TI            2.0           290000.0
#
#         Tiene_carro                  Vivienda
# 0               1.0    Departamento alquilado
# 1               1.0    Departamento alquilado
# 2               1.0  Casa/Departamento propio
# 3               0.0  Casa/Departamento propio
# 4               0.0  Casa/Departamento propio
# ...             ...                       ...
# 383219          1.0  Casa/Departamento propio
# 383220          0.0  Casa/Departamento propio
# 383221          0.0  Casa/Departamento propio
# 383222          NaN                      None
# 383223          0.0  Casa/Departamento propio
#
# [383224 rows x 11 columns]

# %% [markdown]
# ¡Misión completada con éxito!
